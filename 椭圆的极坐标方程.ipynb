# %%
import numpy as np
import matplotlib.pyplot as plt
ran = 0.9
theta = np.linspace(-ran*np.pi, ran*np.pi, 60)
e = 0
p = 2
r = e*p/(1-e*np.cos(theta))
a = plt.subplot(111,projection='polar')
a.plot(theta,r,'-',c='r')
plt.show()
